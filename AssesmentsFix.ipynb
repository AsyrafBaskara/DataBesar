# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Membaca .csv
df = pd.read_csv('Dataset/assessments.csv')

# %%
# Membaca Informasi basic mengenai .csv
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206 entries, 0 to 205
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   code_module        206 non-null    object
#  1   code_presentation  206 non-null    object
#  2   id_assessment      206 non-null    int64
#  3   assessment_type    206 non-null    object
#  4   date               195 non-null    float64
#  5   weight             206 non-null    float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 9.8+ KB

# %%
# Menampilkan 5 row awal pada .csv
df.head()
# Out:
#   code_module code_presentation  id_assessment assessment_type   date  weight
# 0         AAA             2013J           1752             TMA   19.0    10.0
# 1         AAA             2013J           1753             TMA   54.0    20.0
# 2         AAA             2013J           1754             TMA  117.0    20.0
# 3         AAA             2013J           1755             TMA  166.0    20.0
# 4         AAA             2013J           1756             TMA  215.0    30.0

# %%
# Mengecek value yang kosong pada .csv
df.isnull().sum()
# Out:
# code_module           0
# code_presentation     0
# id_assessment         0
# assessment_type       0
# date                 11
# weight                0
# dtype: int64

# %%
# Set style
sns.set_style("whitegrid")

# Initialize the figure
plt.figure(figsize=(20,20))

# %%
# Subplot 1: Jumlah Asesmen berdasarkan Tipe Asesmen
sns.countplot(x='assessment_type', data=df, palette='viridis')
plt.title('Jumlah Asesmen berdasarkan Tipe Asesmen')
plt.xlabel('Tipe Asesmen')
plt.ylabel('Jumlah')
plt.tight_layout()
plt.show()

# Diagram batang yang menunjukkan jumlah asesmen untuk 
# setiap tipe asesmen.

# %%
# Subplot 2: Distribusi Bobot Asesmen
sns.histplot(df['weight'], bins=30, kde=True, color='blue')
plt.title('Distribusi Bobot Asesmen')
plt.xlabel('Bobot Asesmen (%)')
plt.ylabel('Frekuensi')
plt.tight_layout()
plt.show()

# Histogram yang menunjukkan distribusi bobot asesmen.

# %%
# Subplot 3: Jumlah Asesmen per Modul
sns.countplot(y='code_module', data=df, palette='viridis')
plt.title('Jumlah Asesmen per Modul')
plt.xlabel('Jumlah')
plt.ylabel('Kode Modul')
plt.tight_layout()
plt.show()

# Diagram batang yang menunjukkan jumlah asesmen untuk setiap modul.

# %%
# Subplot 4: Jumlah Asesmen per Presentasi
sns.countplot(y='code_presentation', data=df, palette='viridis')
plt.title('Jumlah Asesmen per Presentasi')
plt.xlabel('Jumlah')
plt.ylabel('Kode Presentasi')
plt.tight_layout()
plt.show()

# Diagram batang yang menunjukkan jumlah asesmen untuk setiap presentasi.

# %%
# Subplot 5: Distribusi Durasi Asesmen
sns.countplot(x='date', data=df, palette='viridis', order=sorted(df['date'].unique()))
plt.title('Distribusi Durasi Asesmen')
plt.xlabel('Minggu Asesmen')
plt.ylabel('Jumlah Asesmen')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Diagram batang yang menunjukkan distribusi asesmen berdasarkan minggu.
