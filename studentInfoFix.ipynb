# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Membaca .csv
df = pd.read_csv('Dataset/studentInfo.csv')

# %%
# Membaca Informasi basic mengenai .csv
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32593 entries, 0 to 32592
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   code_module           32593 non-null  object
#  1   code_presentation     32593 non-null  object
#  2   id_student            32593 non-null  int64
#  3   gender                32593 non-null  object
#  4   region                32593 non-null  object
#  5   highest_education     32593 non-null  object
#  6   imd_band              31482 non-null  object
#  7   age_band              32593 non-null  object
#  8   num_of_prev_attempts  32593 non-null  int64
#  9   studied_credits       32593 non-null  int64
#  10  disability            32593 non-null  object
#  11  final_result          32593 non-null  object
# dtypes: int64(3), object(9)
# memory usage: 3.0+ MB

# %%
# Menampilkan 5 row awal pada .csv
df.head()
# Out:
#   code_module code_presentation  id_student gender                region  \
# 0         AAA             2013J       11391      M   East Anglian Region
# 1         AAA             2013J       28400      F              Scotland
# 2         AAA             2013J       30268      F  North Western Region
# 3         AAA             2013J       31604      F     South East Region
# 4         AAA             2013J       32885      F  West Midlands Region
#
#        highest_education imd_band age_band  num_of_prev_attempts  \
# 0       HE Qualification  90-100%     55<=                     0
# 1       HE Qualification   20-30%    35-55                     0
# 2  A Level or Equivalent   30-40%    35-55                     0
# 3  A Level or Equivalent   50-60%    35-55                     0
# 4     Lower Than A Level   50-60%     0-35                     0
#
#    studied_credits disability final_result
# 0              240          N         Pass
# 1               60          N         Pass
# ...

# %%
# Mengecek value yang kosong pada .csv
df.isnull().sum()
# Out:
# code_module                0
# code_presentation          0
# id_student                 0
# gender                     0
# region                     0
# highest_education          0
# imd_band                1111
# age_band                   0
# num_of_prev_attempts       0
# studied_credits            0
# disability                 0
# final_result               0
# dtype: int64

# %%
# Set style
sns.set_style("whitegrid")

# Initialize the figure
plt.figure(figsize=(20,20))

# %%
# 1. Distribusi Mahasiswa berdasarkan Gender
sns.countplot(data=df, x='gender')
plt.title('Distribusi Mahasiswa berdasarkan Gender')
plt.xlabel('Gender')
plt.ylabel('Jumlah Mahasiswa')
plt.show()

# %%
# 2. Distribusi Mahasiswa berdasarkan Region
sns.countplot(data=df, y='region')
plt.title('Distribusi Mahasiswa berdasarkan Region')
plt.xlabel('Jumlah Mahasiswa')
plt.ylabel('Region')
plt.show()

# Menunjukkan distribusi jumlah mahasiswa di berbagai region.

# %%
# 3. Jumlah Mahasiswa berdasarkan Tingkat Pendidikan Terakhir
sns.countplot(data=df, y='highest_education')
plt.title('Jumlah Mahasiswa berdasarkan Tingkat Pendidikan Terakhir')
plt.xlabel('Jumlah Mahasiswa')
plt.ylabel('Tingkat Pendidikan Terakhir')
plt.show()

# Menunjukkan jumlah mahasiswa berdasarkan latar belakang pendidikan terakhir mereka.

# %%
# 4. Proporsi Mahasiswa dengan Kecacatan
sns.countplot(data=df, x='disability')
plt.title('Proporsi Mahasiswa dengan Kecacatan')
plt.xlabel('Kecacatan')
plt.ylabel('Jumlah Mahasiswa')
plt.show()

# Memberikan informasi proporsi mahasiswa yang memiliki kecacatan.

# %%
# 5. Distribusi Hasil Akhir Mahasiswa
sns.countplot(data=df, x='final_result')
plt.title('Distribusi Hasil Akhir Mahasiswa')
plt.xlabel('Hasil Akhir')
plt.ylabel('Jumlah Mahasiswa')
plt.show()

# Menunjukkan distribusi jumlah mahasiswa untuk setiap kategori hasil akhir.
